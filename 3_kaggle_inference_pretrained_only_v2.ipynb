# %% [markdown]
# # Phase 3 v2 — Kaggle Inference (vLLM Few-Shot, No LoRA, Larger Models)
#
# Runs 3 pretrained SLMs with vLLM using few-shot prompting. No LoRA adapters.
# Combines predictions via character-level majority voting.
#
# | Model | Size | tp | Family |
# |-------|------|----|--------|
# | `meta-llama/Meta-Llama-3.1-8B-Instruct` | 8B | 2 | LLaMA |
# | `Qwen/Qwen3-8B` | 8B | 2 | Qwen |
# | `mistralai/Mistral-7B-Instruct-v0.3` | 7B | 2 | Mistral |
#
# **Hardware**: T4 x2 on Kaggle (internet OFF) — float16 only (CC 7.5, no bfloat16)
#
# Models run sequentially; each engine is destroyed before the next loads.
#
# | | |
# |---|---|
# | **Wheels** | `/kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels` |
# | **Llama-3.1-8B** | `/kaggle/input/notebooks/natbrian/llama-3-1-8b-instruct/models/llama_31_8B_Instruct` |
# | **Qwen3-8B** | `/kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-qwen3-8b/models/qwen3_8b` |
# | **Mistral-7B-v0.3** | `/kaggle/input/notebooks/natbrian/mistral-7b-instruct-v0-3/models/mistral_7b_instruct_v03` |
# | **Output** | `/kaggle/working/submission.csv`, `/kaggle/working/timing.log` |

# %%
import os
import sys
import shutil
import subprocess
import site
from pathlib import Path

# =========================
# CONFIG
# =========================
WHEELS = "/kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels"
PKG_DIR = "/kaggle/working/pkgs"

# Same package specs — pip finds the matching wheels in WHEELS
PACKAGES = [
    "vllm==0.17.1",
    "transformers==4.56.0",
    "rapidfuzz>=3.0.0",
    "protobuf<6",
    "huggingface-hub>=0.34.0,<1.0",
    "msgspec>=0.18.0",
    "peft>=0.15.0",
    "accelerate>=1.0.0",
    "bitsandbytes>=0.45.0",
]

subprocess.check_call([
    sys.executable, "-m", "pip", "install",
    "--no-index",
    "--find-links", WHEELS,
    *PACKAGES,
])

# =========================
# VERIFY
# =========================
import torch
import transformers
import vllm
import rapidfuzz
import huggingface_hub
import msgspec
import google.protobuf

def where(mod):
    """Show where a module is loaded from."""
    return getattr(mod, "__file__", "builtin/namespace")

print("\n==== VERSION CHECK ====")
print(f"torch:            {torch.__version__}")
print(f"transformers:     {transformers.__version__}  ({where(transformers)})")
print(f"vllm:             {vllm.__version__}  ({where(vllm)})")
print(f"rapidfuzz:        {rapidfuzz.__version__}  ({where(rapidfuzz)})")
print(f"huggingface_hub:  {huggingface_hub.__version__}  ({where(huggingface_hub)})")
print(f"msgspec:          {msgspec.__version__}  ({where(msgspec)})")
print(f"protobuf:         {google.protobuf.__version__}  ({where(google.protobuf)})")

# Quick check: protobuf should now load from PKG_DIR
proto_path = where(google.protobuf)
if PKG_DIR not in proto_path:
    print(f"\n⚠ WARNING: protobuf still loading from outside PKG_DIR: {proto_path}")
else:
    print(f"\n✓ protobuf correctly loading from PKG_DIR")

print("\n==== CUDA ====")
print(f"CUDA available: {torch.cuda.is_available()}")
for i in range(torch.cuda.device_count()):
    p = torch.cuda.get_device_properties(i)
    print(f"GPU {i}: {p.name} | {p.total_memory/1024**3:.1f} GB | CC {p.major}.{p.minor}")
# Out:
# Looking in links: /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/vllm-0.17.1-cp38-abi3-manylinux_2_31_x86_64.whl
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/transformers-4.56.0-py3-none-any.whl
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/rapidfuzz-3.14.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl
# Requirement already satisfied: protobuf<6 in /usr/local/lib/python3.12/dist-packages (5.29.5)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/huggingface_hub-0.36.2-py3-none-any.whl
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/msgspec-0.21.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl
# Requirement already satisfied: peft>=0.15.0 in /usr/local/lib/python3.12/dist-packages (0.18.1)
# Requirement already satisfied: accelerate>=1.0.0 in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (2025.11.3)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (6.2.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (5.9.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (0.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (2.0.2)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (4.67.3)
# Requirement already satisfied: blake3 in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (1.0.8)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (9.0.0)
# Requirement already satisfied: tokenizers>=0.21.1 in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (0.22.2)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/protobuf-5.29.6-cp38-abi3-manylinux2014_x86_64.whl
# Requirement already satisfied: fastapi>=0.115.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm==0.17.1) (0.133.0)
# Requirement already satisfied: aiohttp>=3.13.3 in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (3.13.3)
# Requirement already satisfied: openai<2.25.0,>=1.99.1 in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (2.23.0)
# Requirement already satisfied: pydantic>=2.12.0 in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (2.12.3)
# Requirement already satisfied: prometheus_client>=0.18.0 in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (0.24.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (11.3.0)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/prometheus_fastapi_instrumentator-7.1.0-py3-none-any.whl (from vllm==0.17.1)
# Requirement already satisfied: tiktoken>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (0.12.0)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/lm_format_enforcer-0.11.3-py3-none-any.whl (from vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/llguidance-1.3.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/outlines_core-0.2.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/diskcache-5.6.3-py3-none-any.whl (from vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/lark-1.2.2-py3-none-any.whl (from vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/xgrammar-0.1.29-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from vllm==0.17.1)
# Requirement already satisfied: typing_extensions>=4.10 in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (4.15.0)
# Requirement already satisfied: filelock>=3.16.1 in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (3.24.3)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/partial_json_parser-0.2.1.1.post7-py3-none-any.whl (from vllm==0.17.1)
# Requirement already satisfied: pyzmq>=25.0.0 in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (26.2.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/gguf-0.18.0-py3-none-any.whl (from vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/mistral_common-1.11.1-py3-none-any.whl (from mistral_common[image]>=1.9.1->vllm==0.17.1)
# Requirement already satisfied: opencv-python-headless>=4.13.0 in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (4.13.0.92)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (6.0.3)
# Requirement already satisfied: six>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (1.17.0)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/setuptools-80.10.2-py3-none-any.whl (from vllm==0.17.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (0.8.2)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/compressed_tensors-0.13.0-py3-none-any.whl (from vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/depyf-0.20.0-py3-none-any.whl (from vllm==0.17.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (3.1.2)
# Requirement already satisfied: watchfiles in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (1.1.1)
# Requirement already satisfied: python-json-logger in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (4.0.0)
# Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (1.13.0)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/pybase64-1.4.3-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (from vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/cbor2-6.0.1-cp312-cp312-manylinux_2_28_x86_64.whl (from vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/ijson-3.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (from vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/setproctitle-1.3.7-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (from vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/openai_harmony-0.0.8-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/anthropic-0.97.0-py3-none-any.whl (from vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/model_hosting_container_standards-0.1.14-py3-none-any.whl (from vllm==0.17.1)
# Requirement already satisfied: mcp in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (1.26.0)
# Requirement already satisfied: grpcio in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (1.78.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/grpcio_reflection-1.71.2-py3-none-any.whl (from vllm==0.17.1)
# Requirement already satisfied: opentelemetry-sdk>=1.27.0 in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (1.38.0)
# Requirement already satisfied: opentelemetry-api>=1.27.0 in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (1.38.0)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/opentelemetry_exporter_otlp-1.41.1-py3-none-any.whl (from vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/opentelemetry_semantic_conventions_ai-0.5.1-py3-none-any.whl (from vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/kaldi_native_fbank-1.22.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/numba-0.61.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from vllm==0.17.1)
# Requirement already satisfied: ray>=2.48.0 in /usr/local/lib/python3.12/dist-packages (from ray[cgraph]>=2.48.0->vllm==0.17.1) (2.54.0)
# Requirement already satisfied: torch==2.10.0 in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (2.10.0+cu128)
# Requirement already satisfied: torchaudio==2.10.0 in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (2.10.0+cu128)
# Requirement already satisfied: torchvision==0.25.0 in /usr/local/lib/python3.12/dist-packages (from vllm==0.17.1) (0.25.0+cu128)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/flashinfer_python-0.6.4-py3-none-any.whl (from vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/nvidia_cudnn_frontend-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (from vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/nvidia_cutlass_dsl-4.5.0.dev0-py3-none-any.whl (from vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/quack_kernels-0.4.1-py3-none-any.whl (from vllm==0.17.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.0) (26.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers==4.56.0) (0.7.0)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/loguru-0.7.3-py3-none-any.whl (from compressed-tensors==0.13.0->vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/astor-0.8.1-py2.py3-none-any.whl (from depyf==0.20.0->vllm==0.17.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from depyf==0.20.0->vllm==0.17.1) (0.4.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/apache_tvm_ffi-0.1.10-cp312-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (from flashinfer-python==0.6.4->vllm==0.17.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from flashinfer-python==0.6.4->vllm==0.17.1) (8.3.1)
# Requirement already satisfied: nvidia-ml-py in /usr/local/lib/python3.12/dist-packages (from flashinfer-python==0.6.4->vllm==0.17.1) (13.590.48)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from flashinfer-python==0.6.4->vllm==0.17.1) (0.9.0)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/interegular-0.3.3-py37-none-any.whl (from lm-format-enforcer==0.11.3->vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from numba==0.61.2->vllm==0.17.1)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->vllm==0.17.1) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->vllm==0.17.1) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->vllm==0.17.1) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->vllm==0.17.1) (2026.2.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->vllm==0.17.1) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->vllm==0.17.1) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->vllm==0.17.1) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->vllm==0.17.1) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->vllm==0.17.1) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->vllm==0.17.1) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->vllm==0.17.1) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->vllm==0.17.1) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->vllm==0.17.1) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->vllm==0.17.1) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->vllm==0.17.1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->vllm==0.17.1) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->vllm==0.17.1) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->vllm==0.17.1) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->vllm==0.17.1) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->vllm==0.17.1) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->vllm==0.17.1) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch==2.10.0->vllm==0.17.1) (1.3.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.13.3->vllm==0.17.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.13.3->vllm==0.17.1) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.13.3->vllm==0.17.1) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.13.3->vllm==0.17.1) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.13.3->vllm==0.17.1) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.13.3->vllm==0.17.1) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.13.3->vllm==0.17.1) (1.22.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.71.0->vllm==0.17.1) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.71.0->vllm==0.17.1) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.71.0->vllm==0.17.1) (0.17.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.71.0->vllm==0.17.1) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.71.0->vllm==0.17.1) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.71.0->vllm==0.17.1) (1.3.1)
# Requirement already satisfied: starlette>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115.0->fastapi[standard]>=0.115.0->vllm==0.17.1) (0.52.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115.0->fastapi[standard]>=0.115.0->vllm==0.17.1) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115.0->fastapi[standard]>=0.115.0->vllm==0.17.1) (0.0.4)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/fastapi_cli-0.0.24-py3-none-any.whl (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm==0.17.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm==0.17.1) (0.0.22)
# Requirement already satisfied: email-validator>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm==0.17.1) (2.3.0)
# Requirement already satisfied: uvicorn>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm==0.17.1) (0.41.0)
# Requirement already satisfied: pydantic-settings>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm==0.17.1) (2.13.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/pydantic_extra_types-2.11.1-py3-none-any.whl (from fastapi[standard]>=0.115.0->vllm==0.17.1)
# Requirement already satisfied: jsonschema>=4.21.1 in /usr/local/lib/python3.12/dist-packages (from mistral_common>=1.9.1->mistral_common[image]>=1.9.1->vllm==0.17.1) (4.26.0)
# Requirement already satisfied: jmespath in /usr/local/lib/python3.12/dist-packages (from model-hosting-container-standards<1.0.0,>=0.1.13->vllm==0.17.1) (1.1.0)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/supervisor-4.3.0-py2.py3-none-any.whl (from model-hosting-container-standards<1.0.0,>=0.1.13->vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/nvidia_cutlass_dsl_libs_base-4.5.0.dev0-cp312-cp312-manylinux_2_28_x86_64.whl (from nvidia-cutlass-dsl>=4.4.0.dev1->vllm==0.17.1)
# Requirement already satisfied: cuda-python>=12.8 in /usr/local/lib/python3.12/dist-packages (from nvidia-cutlass-dsl-libs-base==4.5.0.dev0->nvidia-cutlass-dsl>=4.4.0.dev1->vllm==0.17.1) (12.9.4)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api>=1.27.0->vllm==0.17.1) (8.7.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/opentelemetry_exporter_otlp_proto_grpc-1.41.1-py3-none-any.whl (from opentelemetry-exporter-otlp>=1.27.0->vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/opentelemetry_exporter_otlp_proto_http-1.41.1-py3-none-any.whl (from opentelemetry-exporter-otlp>=1.27.0->vllm==0.17.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.41.1->opentelemetry-exporter-otlp>=1.27.0->vllm==0.17.1) (1.72.0)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/opentelemetry_exporter_otlp_proto_common-1.41.1-py3-none-any.whl (from opentelemetry-exporter-otlp-proto-grpc==1.41.1->opentelemetry-exporter-otlp>=1.27.0->vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/opentelemetry_proto-1.41.1-py3-none-any.whl (from opentelemetry-exporter-otlp-proto-grpc==1.41.1->opentelemetry-exporter-otlp>=1.27.0->vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/opentelemetry_sdk-1.41.1-py3-none-any.whl (from vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/opentelemetry_api-1.41.1-py3-none-any.whl (from vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/opentelemetry_semantic_conventions-0.62b1-py3-none-any.whl (from opentelemetry-sdk>=1.27.0->vllm==0.17.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.12.0->vllm==0.17.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.12.0->vllm==0.17.1) (2.41.4)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/torch_c_dlpack_ext-0.1.5-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (from quack-kernels>=0.2.7->vllm==0.17.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ray>=2.48.0->ray[cgraph]>=2.48.0->vllm==0.17.1) (1.1.2)
# Requirement already satisfied: cupy-cuda12x in /usr/local/lib/python3.12/dist-packages (from ray[cgraph]>=2.48.0->vllm==0.17.1) (14.0.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->vllm==0.17.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->vllm==0.17.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->vllm==0.17.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->vllm==0.17.1) (2026.1.4)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/lib/python3.12/dist-packages (from mcp->vllm==0.17.1) (0.4.3)
# Requirement already satisfied: pyjwt>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.10.1->mcp->vllm==0.17.1) (2.11.0)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from mcp->vllm==0.17.1) (3.2.0)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from email-validator>=2.0.0->fastapi[standard]>=0.115.0->vllm==0.17.1) (2.8.0)
# Requirement already satisfied: typer>=0.16.0 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm==0.17.1) (0.24.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/rich_toolkit-0.19.7-py3-none-any.whl (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm==0.17.1)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/fastapi_cloud_cli-0.17.1-py3-none-any.whl (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm==0.17.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic>=0.71.0->vllm==0.17.1) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic>=0.71.0->vllm==0.17.1) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.27.0->vllm==0.17.1) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.10.0->vllm==0.17.1) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.21.1->mistral_common>=1.9.1->mistral_common[image]>=1.9.1->vllm==0.17.1) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.21.1->mistral_common>=1.9.1->mistral_common[image]>=1.9.1->vllm==0.17.1) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.21.1->mistral_common>=1.9.1->mistral_common[image]>=1.9.1->vllm==0.17.1) (0.30.0)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/pycountry-26.2.16-py3-none-any.whl (from pydantic-extra-types[pycountry]>=2.10.5->mistral_common>=1.9.1->mistral_common[image]>=1.9.1->vllm==0.17.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings>=2.0.0->fastapi[standard]>=0.115.0->vllm==0.17.1) (1.2.1)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.10.1->mcp->vllm==0.17.1) (43.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.10.0->vllm==0.17.1) (1.3.0)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm==0.17.1) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm==0.17.1) (0.22.1)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm==0.17.1) (15.0.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp->vllm==0.17.1) (2.0.0)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/rignore-0.7.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm==0.17.1)
# Requirement already satisfied: sentry-sdk>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm==0.17.1) (2.53.0)
# Processing /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-pip-wheel-v2/wheels/fastar-0.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm==0.17.1)
# Requirement already satisfied: rich>=13.7.1 in /usr/local/lib/python3.12/dist-packages (from rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm==0.17.1) (13.9.4)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.16.0->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm==0.17.1) (1.5.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp->vllm==0.17.1) (3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm==0.17.1) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm==0.17.1) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm==0.17.1) (0.1.2)
# Installing collected packages: supervisor, setuptools, setproctitle, rignore, rapidfuzz, pycountry, pybase64, protobuf, partial-json-parser, outlines_core, nvidia-cudnn-frontend, msgspec, loguru, llvmlite, llguidance, lark, kaldi-native-fbank, interegular, ijson, fastar, diskcache, cbor2, astor, apache-tvm-ffi, opentelemetry-proto, opentelemetry-api, numba, huggingface-hub, grpcio-reflection, gguf, depyf, rich-toolkit, pydantic-extra-types, prometheus-fastapi-instrumentator, opentelemetry-semantic-conventions, opentelemetry-exporter-otlp-proto-common, openai-harmony, nvidia-cutlass-dsl-libs-base, lm-format-enforcer, anthropic, transformers, torch-c-dlpack-ext, opentelemetry-sdk, nvidia-cutlass-dsl, model-hosting-container-standards, fastapi-cloud-cli, fastapi-cli, bitsandbytes, xgrammar, quack-kernels, opentelemetry-semantic-conventions-ai, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, mistral_common, flashinfer-python, compressed-tensors, opentelemetry-exporter-otlp, vllm
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.43.0
#     Uninstalling llvmlite-0.43.0:
#       Successfully uninstalled llvmlite-0.43.0
#   Attempting uninstall: lark
#     Found existing installation: lark 1.3.1
#     Uninstalling lark-1.3.1:
#       Successfully uninstalled lark-1.3.1
#   Attempting uninstall: opentelemetry-proto
#     Found existing installation: opentelemetry-proto 1.38.0
#     Uninstalling opentelemetry-proto-1.38.0:
#       Successfully uninstalled opentelemetry-proto-1.38.0
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.38.0
#     Uninstalling opentelemetry-api-1.38.0:
#       Successfully uninstalled opentelemetry-api-1.38.0
#   Attempting uninstall: numba
#     Found existing installation: numba 0.60.0
#     Uninstalling numba-0.60.0:
#       Successfully uninstalled numba-0.60.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.4.1
#     Uninstalling huggingface_hub-1.4.1:
#       Successfully uninstalled huggingface_hub-1.4.1
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.59b0
#     Uninstalling opentelemetry-semantic-conventions-0.59b0:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.59b0
#   Attempting uninstall: opentelemetry-exporter-otlp-proto-common
#     Found existing installation: opentelemetry-exporter-otlp-proto-common 1.38.0
#     Uninstalling opentelemetry-exporter-otlp-proto-common-1.38.0:
#       Successfully uninstalled opentelemetry-exporter-otlp-proto-common-1.38.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.38.0
#     Uninstalling opentelemetry-sdk-1.38.0:
#       Successfully uninstalled opentelemetry-sdk-1.38.0
#   Attempting uninstall: opentelemetry-exporter-otlp-proto-http
#     Found existing installation: opentelemetry-exporter-otlp-proto-http 1.38.0
#     Uninstalling opentelemetry-exporter-otlp-proto-http-1.38.0:
#       Successfully uninstalled opentelemetry-exporter-otlp-proto-http-1.38.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.35.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-adk 1.25.1 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# google-adk 1.25.1 requires opentelemetry-api<1.40.0,>=1.36.0, but you have opentelemetry-api 1.41.1 which is incompatible.
# google-adk 1.25.1 requires opentelemetry-sdk<1.40.0,>=1.36.0, but you have opentelemetry-sdk 1.41.1 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.41.1 which is incompatible.
# Successfully installed anthropic-0.97.0 apache-tvm-ffi-0.1.10 astor-0.8.1 bitsandbytes-0.49.2 cbor2-6.0.1 compressed-tensors-0.13.0 depyf-0.20.0 diskcache-5.6.3 fastapi-cli-0.0.24 fastapi-cloud-cli-0.17.1 fastar-0.11.0 flashinfer-python-0.6.4 gguf-0.18.0 grpcio-reflection-1.71.2 huggingface-hub-0.36.2 ijson-3.5.0 interegular-0.3.3 kaldi-native-fbank-1.22.3 lark-1.2.2 llguidance-1.3.0 llvmlite-0.44.0 lm-format-enforcer-0.11.3 loguru-0.7.3 mistral_common-1.11.1 model-hosting-container-standards-0.1.14 msgspec-0.21.1 numba-0.61.2 nvidia-cudnn-frontend-1.18.0 nvidia-cutlass-dsl-4.5.0.dev0 nvidia-cutlass-dsl-libs-base-4.5.0.dev0 openai-harmony-0.0.8 opentelemetry-api-1.41.1 opentelemetry-exporter-otlp-1.41.1 opentelemetry-exporter-otlp-proto-common-1.41.1 opentelemetry-exporter-otlp-proto-grpc-1.41.1 opentelemetry-exporter-otlp-proto-http-1.41.1 opentelemetry-proto-1.41.1 opentelemetry-sdk-1.41.1 opentelemetry-semantic-conventions-0.62b1 opentelemetry-semantic-conventions-ai-0.5.1 outlines_core-0.2.11 partial-json-parser-0.2.1.1.post7 prometheus-fastapi-instrumentator-7.1.0 protobuf-5.29.6 pybase64-1.4.3 pycountry-26.2.16 pydantic-extra-types-2.11.1 quack-kernels-0.4.1 rapidfuzz-3.14.5 rich-toolkit-0.19.7 rignore-0.7.6 setproctitle-1.3.7 setuptools-80.10.2 supervisor-4.3.0 torch-c-dlpack-ext-0.1.5 transformers-4.56.0 vllm-0.17.1 xgrammar-0.1.29
#
# ==== VERSION CHECK ====
# torch:            2.10.0+cu128
# transformers:     4.56.0  (/usr/local/lib/python3.12/dist-packages/transformers/__init__.py)
# vllm:             0.17.1  (/usr/local/lib/python3.12/dist-packages/vllm/__init__.py)
# rapidfuzz:        3.14.5  (/usr/local/lib/python3.12/dist-packages/rapidfuzz/__init__.py)
# huggingface_hub:  0.36.2  (/usr/local/lib/python3.12/dist-packages/huggingface_hub/__init__.py)
# msgspec:          0.21.1  (/usr/local/lib/python3.12/dist-packages/msgspec/__init__.py)
# protobuf:         5.29.6  (/usr/local/lib/python3.12/dist-packages/google/protobuf/__init__.py)
#
# ⚠ WARNING: protobuf still loading from outside PKG_DIR: /usr/local/lib/python3.12/dist-packages/google/protobuf/__init__.py
#
# ==== CUDA ====
# CUDA available: True
# GPU 0: Tesla T4 | 14.6 GB | CC 7.5
# GPU 1: Tesla T4 | 14.6 GB | CC 7.5

# %%
import contextlib, gc, json, logging, re, sys
from pathlib import Path
from typing import Optional

import numpy as np
import pandas as pd
import torch
from rapidfuzz.fuzz import partial_ratio_alignment
from tqdm import tqdm
from transformers import AutoTokenizer

from vllm import LLM, SamplingParams
from vllm.config import AttentionConfig
from vllm.v1.attention.backends.registry import AttentionBackendEnum
# GuidedDecodingParams removed in vLLM 0.12 → replaced by StructuredOutputsParams
from vllm.sampling_params import StructuredOutputsParams

try:
    from vllm.distributed.parallel_state import destroy_model_parallel
except ImportError:
    def destroy_model_parallel(): pass

print(f"vLLM version: {__import__('vllm').__version__}")

# T4 CC=7.5 — no native bfloat16
_DTYPE = torch.float16

CONFIG = {
    "DATA_DIR":              Path("/kaggle/input/competitions/nbme-score-clinical-patient-notes"),
    "OUTPUT_DIR":            Path("/kaggle/working"),
    "GPU_MEM_UTIL":          0.90,
    "MAX_MODEL_LEN":         1024,
    "MAX_NEW_TOKENS":        128,
    "LLM_TEMPERATURE":       0.0,
    "MAX_SPANS_PER_FEATURE": 10,
    "VOTE_THRESHOLD":        2,
    "FUZZY_SCORE_CUTOFF":    70.0,
    "SEED":                  42,
}

MODEL_REGISTRY = [
    {
        # Meta-Llama-3.1-8B-Instruct — ~16GB fp16 — tp=2 for KV cache headroom
        # Requires HF license acceptance + pre-downloaded Kaggle dataset
        "name":              "llama_31_8B_Instruct",
        "model_path":        "/kaggle/input/notebooks/natbrian/llama-3-1-8b-instruct/models/llama_31_8B_Instruct",
        "vllm_dtype":        "half",
        "tp":                2,
        "enable_thinking":   None,
        "trust_remote_code": False,
    },
    {
        # Qwen3-8B — ~16GB fp16 — tp=2
        "name":              "qwen3_8b",
        "model_path":        "/kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-qwen3-8b/models/qwen3_8b",
        "vllm_dtype":        "half",
        "tp":                2,
        "enable_thinking":   False,
        "trust_remote_code": False,
    },
    {
        # Mistral-7B-Instruct-v0.3 — ~14GB fp16 — tp=2
        # Confirmed float16 on T4 (no bfloat16 needed)
        "name":              "mistral_7b_instruct_v03",
        "model_path":        "/kaggle/input/notebooks/natbrian/mistral-7b-instruct-v0-3/models/mistral_7b_instruct_v03",
        "vllm_dtype":        "half",
        "tp":                2,
        "enable_thinking":   None,
        "trust_remote_code": False,
    },
]

# ── Few-shot examples ──────────────────────────────────────────────────────────
FEW_SHOT_EXAMPLES = [
    {
        "note":    "68 yo male with a 30-pack-year smoking history presents with hemoptysis and a 15-lb weight loss over 3 months.",
        "feature": "smoking history",
        "output":  '{"spans": ["30-pack-year smoking history"]}',
    },
    {
        "note":    "Patient is a 45 yo female with hypertension and type 2 diabetes mellitus. She takes metformin and lisinopril daily. She denies chest pain but reports occasional shortness of breath on exertion.",
        "feature": "current medications",
        "output":  '{"spans": ["metformin", "lisinopril"]}',
    },
    {
        "note":    "32 yo male presents with 3-day history of fever, productive cough with yellowish sputum, and left-sided pleuritic chest pain. Exam reveals decreased breath sounds at left base and dullness to percussion.",
        "feature": "pleuritic chest pain",
        "output":  '{"spans": ["left-sided pleuritic chest pain"]}',
    },
    {
        "note":    "55 yo woman with a history of rheumatoid arthritis managed with methotrexate. She presents for routine follow-up. No joint swelling noted today. Labs show WBC 3.2 and mild transaminase elevation.",
        "feature": "family history of autoimmune disease",
        "output":  '{"spans": []}',
    },
    {
        "note":    "Patient reports dull, aching pain in the right upper quadrant that worsens after fatty meals. She also notes nausea and one episode of vomiting. No jaundice.",
        "feature": "pain characteristics",
        "output":  '{"spans": ["dull, aching pain in the right upper quadrant", "worsens after fatty meals"]}',
    },
]

SYSTEM_PROMPT = (
    "You are a clinical NLP specialist. "
    "Given a patient note and a clinical feature, extract the EXACT verbatim text spans "
    "from the note that express that feature.\n"
    "Rules:\n"
    "  1. Copy text character-for-character from the note — do NOT paraphrase or rephrase.\n"
    "  2. Only include spans that are literally present in the note.\n"
    "  3. If the feature is absent from the note, return an empty list.\n"
    "  4. Output ONLY valid JSON — no markdown, no explanation, no extra text.\n"
    'Format: {"spans": ["exact text 1", "exact text 2"]}'
)

# ── Timing log to /kaggle/working/timing.log ──────────────────────────────────
import time as _time_module
_NOTEBOOK_START = _time_module.time()

_LOG_PATH = Path("/kaggle/working/timing.log")

def _tlog(msg: str) -> None:
    """Write timestamped line to timing.log AND stdout."""
    elapsed = _time_module.time() - _NOTEBOOK_START
    h, rem  = divmod(int(elapsed), 3600)
    m, s    = divmod(rem, 60)
    line    = f"[{h:02d}:{m:02d}:{s:02d}] {msg}"
    print(line, flush=True)
    with open(_LOG_PATH, "a") as _f:
        _f.write(line + "\n")

# Clear / init log file
_LOG_PATH.write_text(f"=== timing.log — notebook started ===\n")
_tlog("Imports done, CONFIG loaded")

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s  [%(levelname)s]  %(message)s",
    handlers=[logging.StreamHandler(sys.stdout)],
)
log = logging.getLogger(__name__)
print("✓ CONFIG, MODEL_REGISTRY loaded")
print(f"  Models: {[m['name'] for m in MODEL_REGISTRY]}")
print(f"  Few-shot examples: {len(FEW_SHOT_EXAMPLES)}")
# Out:
# 2026-05-02 07:28:10.228272: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777706890.426387      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777706890.493580      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777706890.987789      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777706890.987827      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777706890.987830      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777706890.987833      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# vLLM version: 0.17.1
# [00:00:00] Imports done, CONFIG loaded
# ✓ CONFIG, MODEL_REGISTRY loaded
#   Models: ['llama_31_8B_Instruct', 'qwen3_8b', 'mistral_7b_instruct_v03']
#   Few-shot examples: 5

# %% [markdown]
# ## Section 1 — Per-Note Regex FSM Constraint

# %%
def _build_char_class(note_chars: set) -> str:
    parts = []
    for ch in sorted(note_chars, key=ord):
        code = ord(ch)
        if code < 0x20 or code == 0x7F: continue
        if ch == ']':    parts.append(r'\]')
        elif ch == '^':  parts.append(r'\^')
        elif ch == '-':  parts.append(r'\-')
        elif ch == '\\': parts.append(r'\\')
        else:            parts.append(ch)
    return '[' + ''.join(parts) + ']' if parts else r'[^\n]'


def build_constraint_regex(pn_history: str, max_spans: int = 10) -> str:
    note_chars = set(pn_history) - {'"', '\\'}
    char_class = _build_char_class(note_chars)
    span_item  = f'"{char_class}*"'
    additional = r'(?:, ' + span_item + r'){0,' + str(max_spans - 1) + r'}'
    opt_list   = r'(?:' + span_item + additional + r')?'
    return r'\{"spans": \[' + opt_list + r'\]}'

print("✓ Section 1: build_constraint_regex defined")
# Out:
# ✓ Section 1: build_constraint_regex defined

# %% [markdown]
# ## Section 2 — Few-Shot Prompt Builder

# %%
def build_few_shot_prompt(feature_text: str, pn_history: str, tokenizer,
                          enable_thinking=None) -> str:
    """
    Build a chat prompt with few-shot examples followed by the target query.
    Alternates user/assistant turns so the model sees the expected output format.
    """
    messages = [{"role": "system", "content": SYSTEM_PROMPT}]

    # Inject few-shot examples as alternating user/assistant turns
    for ex in FEW_SHOT_EXAMPLES:
        user_content = (
            f'Note: "{ex["note"]}"\n'
            f'Feature: {ex["feature"]}'
        )
        if enable_thinking is False:
            user_content += "\n\n/no_think"
        messages.append({"role": "user",      "content": user_content})
        messages.append({"role": "assistant", "content": ex["output"]})

    # Actual query
    query_content = (
        f'Note: "{pn_history.strip()}"\n'
        f'Feature: {feature_text}'
    )
    if enable_thinking is False:
        query_content += "\n\n/no_think"
    messages.append({"role": "user", "content": query_content})

    kwargs = dict(tokenize=False, add_generation_prompt=True)
    if enable_thinking is not None:
        try:
            return tokenizer.apply_chat_template(messages, enable_thinking=enable_thinking, **kwargs)
        except TypeError:
            pass
    return tokenizer.apply_chat_template(messages, **kwargs)

print("✓ Section 2: build_few_shot_prompt defined")
# Out:
# ✓ Section 2: build_few_shot_prompt defined

# %% [markdown]
# ## Section 3 — vLLM Engine Lifecycle

# %%
def init_engine(model_path: str, model_spec: dict, cfg: dict) -> LLM:
    attn_cfg = AttentionConfig(backend=AttentionBackendEnum.TRITON_ATTN)
    log.info(f"  [{model_spec['name']}] Initialising vLLM engine (tp={model_spec['tp']}) ...")
    llm = LLM(
        model                  = model_path,
        dtype                  = model_spec["vllm_dtype"],
        tensor_parallel_size   = model_spec["tp"],
        gpu_memory_utilization = cfg["GPU_MEM_UTIL"],
        max_model_len          = cfg["MAX_MODEL_LEN"],
        enforce_eager          = True,
        trust_remote_code      = model_spec.get("trust_remote_code", False),
        seed                   = cfg["SEED"],
        attention_config       = attn_cfg,
    )
    log.info(f"  [{model_spec['name']}] vLLM engine ready.")
    return llm


def destroy_engine(llm, model_name: str) -> None:
    log.info(f"  [{model_name}] Destroying vLLM engine ...")
    destroy_model_parallel()
    with contextlib.suppress(Exception):
        torch.distributed.destroy_process_group()
    del llm
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        torch.cuda.synchronize()
        free_gb  = torch.cuda.mem_get_info()[0] / 1024**3
        total_gb = torch.cuda.mem_get_info()[1] / 1024**3
        log.info(f"  [{model_name}] VRAM after cleanup: {free_gb:.1f}/{total_gb:.1f} GB free")

print("✓ Section 3: init_engine, destroy_engine defined")
# Out:
# ✓ Section 3: init_engine, destroy_engine defined

# %% [markdown]
# ## Section 4 — vLLM Inference Runner

# %%
def _parse_json_output(raw_text: str) -> list:
    raw_text = re.sub(r'<think>.*?</think>', '', raw_text, flags=re.DOTALL).strip()
    try:
        parsed = json.loads(raw_text)
        return [s.strip() for s in parsed.get("spans", []) if isinstance(s, str) and s.strip()]
    except (json.JSONDecodeError, AttributeError):
        match = re.search(r'\{.*\}', raw_text, re.DOTALL)
        if match:
            try:
                parsed = json.loads(match.group())
                return [s.strip() for s in parsed.get("spans", []) if isinstance(s, str) and s.strip()]
            except json.JSONDecodeError:
                pass
    return []


def run_inference_vllm(llm, test_rows, pn_map, feat_map, tokenizer,
                       cfg, model_spec) -> list:
    model_name      = model_spec["name"]
    enable_thinking = model_spec.get("enable_thinking")
    log.info(f"  [{model_name}] Building few-shot prompts ...")
    prompts, params_list = [], []

    for _, row in test_rows.iterrows():
        pn_history   = pn_map.get(row["pn_num"], "").replace("\n", " ").strip()
        feature_text = feat_map.get((row["case_num"], row["feature_num"]), "")
        prompts.append(build_few_shot_prompt(feature_text, pn_history, tokenizer, enable_thinking))
        regex  = build_constraint_regex(pn_history, cfg["MAX_SPANS_PER_FEATURE"])
        # backend is set internally by vLLM 0.17.1 — do not pass to constructor
        params_list.append(SamplingParams(
            temperature=cfg["LLM_TEMPERATURE"],
            max_tokens=cfg["MAX_NEW_TOKENS"],
            structured_outputs=StructuredOutputsParams(regex=regex),
        ))

    log.info(f"  [{model_name}] Running vLLM inference on {len(prompts)} rows ...")
    outputs   = llm.generate(prompts=prompts, sampling_params=params_list)
    all_spans = []
    for output in tqdm(outputs, desc=f"  [{model_name}] Parsing", leave=False):
        raw = output.outputs[0].text.strip() if output.outputs else ""
        all_spans.append(_parse_json_output(raw))

    n_nonempty = sum(1 for s in all_spans if s)
    log.info(f"  [{model_name}] Done — non-empty: {n_nonempty}/{len(all_spans)}")
    return all_spans

print("✓ Section 4: _parse_json_output, run_inference_vllm defined")
# Out:
# ✓ Section 4: _parse_json_output, run_inference_vllm defined

# %% [markdown]
# ## Section 5 — Character-Level Majority Voting

# %%
def spans_to_char_array(span_locations: list, note_len: int) -> np.ndarray:
    arr = np.zeros(note_len, dtype=np.uint8)
    for start, end in span_locations:
        arr[max(0, start):min(note_len, end)] = 1
    return arr


def char_array_to_spans(arr: np.ndarray) -> list:
    spans, n, i = [], len(arr), 0
    while i < n:
        if arr[i] == 1:
            start = i
            while i < n and arr[i] == 1: i += 1
            spans.append((start, i))
        else:
            i += 1
    return spans


def locate_span_in_note(span_text: str, pn_history: str,
                        score_cutoff: float = 70.0) -> Optional[tuple]:
    span_text = span_text.strip()
    if not span_text or not pn_history: return None
    idx = pn_history.find(span_text)
    if idx != -1: return (idx, idx + len(span_text))
    idx = pn_history.lower().find(span_text.lower())
    if idx != -1: return (idx, idx + len(span_text))
    result = partial_ratio_alignment(span_text, pn_history, score_cutoff=score_cutoff)
    if result is not None: return (result.dest_start, result.dest_end)
    return None


def character_level_majority_vote(model_predictions, test_rows, pn_map,
                                  vote_threshold=2, fuzzy_cutoff=70.0) -> list:
    n_models, n_rows = len(model_predictions), len(test_rows)
    log.info(f"Majority vote ({n_models} models, threshold={vote_threshold}/{n_models}) ...")
    final_spans = []

    for seq_idx, (_, row) in enumerate(tqdm(test_rows.iterrows(), total=n_rows, desc="Majority vote")):
        pn_history = pn_map.get(row["pn_num"], "")
        note_len   = len(pn_history)
        if note_len == 0:
            final_spans.append([]); continue

        vote_array = np.zeros(note_len, dtype=np.int8)
        for preds in model_predictions:
            locs = [loc for text in preds[seq_idx]
                    if (loc := locate_span_in_note(text, pn_history, fuzzy_cutoff)) is not None]
            if locs:
                vote_array += spans_to_char_array(locs, note_len)

        consensus = (vote_array >= vote_threshold).astype(np.uint8)
        for i, ch in enumerate(pn_history):
            if ch in (' ', '\t', '\n', '\r') and consensus[i]:
                is_start = (i == 0 or consensus[i-1] == 0)
                is_end   = (i == note_len-1 or consensus[i+1] == 0)
                if is_start or is_end: consensus[i] = 0

        final_spans.append(char_array_to_spans(consensus))

    log.info(f"Vote complete — non-empty: {sum(1 for s in final_spans if s)}/{n_rows}")
    return final_spans

print("✓ Section 5: majority vote defined")
# Out:
# ✓ Section 5: majority vote defined

# %% [markdown]
# ## Section 6 — Submission Formatter

# %%
def format_location_string(spans: list, pn_history: str) -> str:
    if not spans: return ""
    clean = []
    for start, end in sorted(spans):
        while start < end and pn_history[start] in (' ', '\t', '\n', '\r'): start += 1
        while end > start and pn_history[end-1] in (' ', '\t', '\n', '\r'): end -= 1
        if start < end: clean.append((start, end))
    merged = []
    for start, end in sorted(clean):
        if merged and start <= merged[-1][1]:
            merged[-1] = (merged[-1][0], max(merged[-1][1], end))
        else:
            merged.append((start, end))
    return ";".join(f"{s} {e}" for s, e in merged) if merged else ""


def build_submission(final_spans: list, test_df: pd.DataFrame, pn_map: dict) -> pd.DataFrame:
    rows = []
    for row_idx, (_, test_row) in enumerate(test_df.iterrows()):
        pn_history = pn_map.get(test_row["pn_num"], "")
        spans      = final_spans[row_idx] if row_idx < len(final_spans) else []
        location   = format_location_string(spans, pn_history)
        rows.append({"id": test_row["id"], "location": location if location else np.nan})
    return pd.DataFrame(rows)

print("✓ Section 6: format_location_string, build_submission defined")
# Out:
# ✓ Section 6: format_location_string, build_submission defined

# %% [markdown]
# ## Run — Generate Submission
#
# Pipeline per model:
# 1. Load pretrained model directly into vLLM (no adapter merge)
# 2. Run batched inference with 5-shot examples + per-note regex constrained decoding
# 3. Destroy engine
#
# Then: character-level majority vote → `submission.csv`

# %%
def main():
    cfg      = CONFIG
    data_dir = cfg["DATA_DIR"]

    _tlog("=== PHASE 3: Kaggle Inference (vLLM Few-Shot, No LoRA) START ===")
    print("\n" + "="*65)
    print("  PHASE 3: Kaggle Inference (vLLM Few-Shot, No LoRA)")
    print(f"  Models: {[m['name'] for m in MODEL_REGISTRY]}")
    print(f"  Few-shot examples: {len(FEW_SHOT_EXAMPLES)}")
    print("="*65 + "\n")

    print("▶ Loading test data ...")
    test_df  = pd.read_csv(data_dir / "test.csv")
    pn_df    = pd.read_csv(data_dir / "patient_notes.csv")
    feat_df  = pd.read_csv(data_dir / "features.csv")
    pn_map   = pn_df.set_index("pn_num")["pn_history"].to_dict()
    feat_map = feat_df.set_index(["case_num", "feature_num"])["feature_text"].to_dict()
    n_rows   = len(test_df)
    print(f"  Test rows: {n_rows}")
    _tlog(f"Data loaded — {n_rows} test rows")

    all_model_predictions = []

    for i, model_spec in enumerate(MODEL_REGISTRY):
        model_name = model_spec["name"]
        model_path = model_spec["model_path"]
        print(f"\n{'='*65}")
        print(f"  Model {i+1}/{len(MODEL_REGISTRY)}: {model_name}  (tp={model_spec['tp']})")
        print(f"  Path: {model_path}")
        print(f"{'='*65}")

        _tlog(f"[{model_name}] START  (model {i+1}/{len(MODEL_REGISTRY)}, tp={model_spec['tp']})")
        _t0 = _time_module.time()

        # use_fast=True avoids slow tokenizer that requires vocab.json
        tokenizer = AutoTokenizer.from_pretrained(
            model_path,
            use_fast=True,
            trust_remote_code=model_spec.get("trust_remote_code", False),
        )
        if tokenizer.pad_token is None:
            tokenizer.pad_token    = tokenizer.eos_token
            tokenizer.pad_token_id = tokenizer.eos_token_id

        _tlog(f"[{model_name}] tokenizer loaded, starting vLLM init ...")
        llm = init_engine(model_path, model_spec, cfg)
        _tlog(f"[{model_name}] vLLM engine ready, starting inference ({n_rows} rows) ...")

        _t_inf = _time_module.time()
        model_spans = run_inference_vllm(llm, test_df, pn_map, feat_map,
                                         tokenizer, cfg, model_spec)
        _inf_sec = _time_module.time() - _t_inf
        _rows_per_sec = n_rows / _inf_sec if _inf_sec > 0 else float("inf")
        _tlog(f"[{model_name}] inference done — {_inf_sec:.1f}s  ({_rows_per_sec:.1f} rows/s)")

        all_model_predictions.append(model_spans)

        destroy_engine(llm, model_name)
        del llm, tokenizer
        gc.collect()

        _model_total = _time_module.time() - _t0
        _tlog(f"[{model_name}] END   — total {_model_total:.1f}s")

    _tlog("Starting character-level majority vote ...")
    print("\n▶ Running character-level majority vote ...")
    effective_threshold = min(cfg["VOTE_THRESHOLD"], len(all_model_predictions))
    final_spans = character_level_majority_vote(
        all_model_predictions, test_df, pn_map,
        vote_threshold=effective_threshold,
        fuzzy_cutoff=cfg["FUZZY_SCORE_CUTOFF"],
    )
    _tlog("Majority vote done")

    submission_df = build_submission(final_spans, test_df, pn_map)
    out_path = cfg["OUTPUT_DIR"] / "submission.csv"
    submission_df.to_csv(out_path, index=False)

    _notebook_total = _time_module.time() - _NOTEBOOK_START
    _h, _rem = divmod(int(_notebook_total), 3600)
    _m, _s   = divmod(_rem, 60)
    _tlog(f"=== DONE — total notebook time {_h:02d}:{_m:02d}:{_s:02d} ===")

    print("\n" + "="*65)
    print(f"  ✓ Submission saved → {out_path}")
    print(f"  Shape: {submission_df.shape}")
    print(f"  Non-empty: {submission_df['location'].notna().sum()} / {len(submission_df)}")
    print(f"  Timing log → /kaggle/working/timing.log")
    print("="*65)
    print(submission_df.head(10).to_string())

main()
# Out:
# [00:00:00] === PHASE 3: Kaggle Inference (vLLM Few-Shot, No LoRA) START ===
#
# =================================================================
#   PHASE 3: Kaggle Inference (vLLM Few-Shot, No LoRA)
#   Models: ['llama_31_8B_Instruct', 'qwen3_8b', 'mistral_7b_instruct_v03']
#   Few-shot examples: 5
# =================================================================
#
# ▶ Loading test data ...
#   Test rows: 5
# [00:00:00] Data loaded — 5 test rows
#
# =================================================================
#   Model 1/3: llama_31_8B_Instruct  (tp=2)
#   Path: /kaggle/input/notebooks/natbrian/llama-3-1-8b-instruct/models/llama_31_8B_Instruct
# =================================================================
# [00:00:00] [llama_31_8B_Instruct] START  (model 1/3, tp=2)
# [00:00:01] [llama_31_8B_Instruct] tokenizer loaded, starting vLLM init ...
# INFO 05-02 07:28:34 [utils.py:238] non-default args: {'dtype': 'half', 'seed': 42, 'max_model_len': 1024, 'tensor_parallel_size': 2, 'disable_log_stats': True, 'enforce_eager': True, 'attention_config': AttentionConfig(backend=<AttentionBackendEnum.TRITON_ATTN: 'vllm.v1.attention.backends.triton_attn.TritonAttentionBackend'>, flash_attn_version=None, use_prefill_decode_attention=False, flash_attn_max_num_splits_for_cuda_graph=32, use_cudnn_prefill=False, use_trtllm_ragged_deepseek_prefill=True, use_trtllm_attention=None, disable_flashinfer_prefill=False, disable_flashinfer_q_quantization=False, use_prefill_query_quantization=False), 'model': '/kaggle/input/notebooks/natbrian/llama-3-1-8b-instruct/models/llama_31_8B_Instruct'}
# INFO 05-02 07:28:58 [model.py:531] Resolved architecture: LlamaForCausalLM
# WARNING 05-02 07:28:58 [model.py:1892] Casting torch.bfloat16 to torch.float16.
# INFO 05-02 07:28:58 [model.py:1554] Using max model len 1024
# INFO 05-02 07:28:59 [scheduler.py:231] Chunked prefill is enabled with max_num_batched_tokens=8192.
# INFO 05-02 07:28:59 [vllm.py:747] Asynchronous scheduling is enabled.
# WARNING 05-02 07:28:59 [vllm.py:781] Enforce eager set, disabling torch.compile and CUDAGraphs. This is equivalent to setting -cc.mode=none -cc.cudagraph_mode=none
# WARNING 05-02 07:28:59 [vllm.py:792] Inductor compilation was disabled by user settings, optimizations settings that are only active during inductor compilation will be ignored.
# INFO 05-02 07:28:59 [vllm.py:957] Cudagraph is disabled under eager mode
# WARNING 05-02 07:29:00 [system_utils.py:152] We must use the `spawn` multiprocessing start method. Overriding VLLM_WORKER_MULTIPROC_METHOD to 'spawn'. See https://docs.vllm.ai/en/latest/usage/troubleshooting.html#python-multiprocessing for more information. Reasons: CUDA is initialized
# 2026-05-02 07:29:12.515533: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777706952.546275      94 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777706952.554147      94 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777706952.574601      94 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777706952.574672      94 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777706952.574679      94 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777706952.574684      94 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (EngineCore_DP0 pid=94) INFO 05-02 07:29:20 [core.py:101] Initializing a V1 LLM engine (v0.17.1) with config: model='/kaggle/input/notebooks/natbrian/llama-3-1-8b-instruct/models/llama_31_8B_Instruct', speculative_config=None, tokenizer='/kaggle/input/notebooks/natbrian/llama-3-1-8b-instruct/models/llama_31_8B_Instruct', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=1024, download_dir=None, load_format=auto, tensor_parallel_size=2, pipeline_parallel_size=1, data_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=True, enable_return_routed_experts=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser='', reasoning_parser_plugin='', enable_in_reasoning=False), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None, kv_cache_metrics=False, kv_cache_metrics_sample=0.01, cudagraph_metrics=False, enable_layerwise_nvtx_tracing=False, enable_mfu_metrics=False, enable_mm_processor_stats=False, enable_logging_iteration_details=False), seed=42, served_model_name=/kaggle/input/notebooks/natbrian/llama-3-1-8b-instruct/models/llama_31_8B_Instruct, enable_prefix_caching=True, enable_chunked_prefill=True, pooler_config=None, compilation_config={'level': None, 'mode': <CompilationMode.NONE: 0>, 'debug_dump_path': None, 'cache_dir': '', 'compile_cache_save_format': 'binary', 'backend': 'inductor', 'custom_ops': ['all'], 'splitting_ops': [], 'compile_mm_encoder': False, 'compile_sizes': [], 'compile_ranges_split_points': [8192], 'inductor_compile_config': {'enable_auto_functionalized_v2': False, 'combo_kernels': True, 'benchmark_combo_kernel': True}, 'inductor_passes': {}, 'cudagraph_mode': <CUDAGraphMode.NONE: 0>, 'cudagraph_num_of_warmups': 0, 'cudagraph_capture_sizes': [], 'cudagraph_copy_inputs': False, 'cudagraph_specialize_lora': True, 'use_inductor_graph_partition': False, 'pass_config': {'fuse_norm_quant': True, 'fuse_act_quant': True, 'fuse_attn_quant': False, 'enable_sp': False, 'fuse_gemm_comms': False, 'fuse_allreduce_rms': False}, 'max_cudagraph_capture_size': 0, 'dynamic_shapes_config': {'type': <DynamicShapesType.BACKED: 'backed'>, 'evaluate_guards': False, 'assume_32_bit_indexing': False}, 'local_cache_dir': None, 'fast_moe_cold_start': True, 'static_all_moe_layers': []}
# (EngineCore_DP0 pid=94) WARNING 05-02 07:29:20 [multiproc_executor.py:945] Reducing Torch parallelism from 2 threads to 1 to avoid unnecessary CPU contention. Set OMP_NUM_THREADS in the external environment to tune this value as needed.
# (EngineCore_DP0 pid=94) INFO 05-02 07:29:20 [multiproc_executor.py:134] DP group leader: node_rank=0, node_rank_within_dp=0, master_addr=127.0.0.1, mq_connect_ip=172.19.2.2 (local), world_size=2, local_world_size=2
# 2026-05-02 07:29:25.744519: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-05-02 07:29:25.745250: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777706965.770825     119 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777706965.772140     120 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777706965.778869     119 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1777706965.780502     120 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777706965.797456     119 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777706965.797486     119 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777706965.797489     119 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777706965.797491     119 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777706965.799558     120 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777706965.799609     120 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777706965.799615     120 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777706965.799620     120 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (Worker pid=120) INFO 05-02 07:29:38 [parallel_state.py:1393] world_size=2 rank=1 local_rank=1 distributed_init_method=tcp://127.0.0.1:39447 backend=nccl
# (Worker pid=119) INFO 05-02 07:29:38 [parallel_state.py:1393] world_size=2 rank=0 local_rank=0 distributed_init_method=tcp://127.0.0.1:39447 backend=nccl
# [W502 07:29:46.771210546 socket.cpp:207] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W502 07:29:46.087997816 socket.cpp:207] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W502 07:29:54.773374108 socket.cpp:207] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# (Worker pid=120) <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.cudart module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.runtime module instead.
# (Worker pid=119) <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.cudart module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.runtime module instead.
# (Worker pid=120) <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.nvrtc module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.nvrtc module instead.
# (Worker pid=119) <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.nvrtc module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.nvrtc module instead.
# (Worker pid=119) INFO 05-02 07:29:54 [pynccl.py:111] vLLM is using nccl==2.27.5
# (Worker pid=119) WARNING 05-02 07:29:55 [symm_mem.py:67] SymmMemCommunicator: Device capability 7.5 not supported, communicator is not available.
# (Worker pid=120) WARNING 05-02 07:29:55 [symm_mem.py:67] SymmMemCommunicator: Device capability 7.5 not supported, communicator is not available.
# (Worker pid=120) INFO 05-02 07:29:55 [parallel_state.py:1715] rank 1 in world size 2 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 1, EP rank N/A, EPLB rank N/A
# (Worker pid=119) INFO 05-02 07:29:55 [parallel_state.py:1715] rank 0 in world size 2 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 0, EP rank N/A, EPLB rank N/A
# (Worker pid=119) INFO 05-02 07:29:56 [base.py:106] Offloader set to NoopOffloader
# (Worker pid=120) INFO 05-02 07:29:56 [base.py:106] Offloader set to NoopOffloader
# (Worker pid=119) (Worker_TP0 pid=119) INFO 05-02 07:29:56 [gpu_model_runner.py:4281] Starting to load model /kaggle/input/notebooks/natbrian/llama-3-1-8b-instruct/models/llama_31_8B_Instruct...
# (Worker pid=119) (Worker_TP0 pid=119) INFO 05-02 07:29:56 [cuda.py:368] Using AttentionBackendEnum.TRITON_ATTN backend.
# (Worker pid=120) (Worker_TP1 pid=120) INFO 05-02 07:29:56 [cuda.py:368] Using AttentionBackendEnum.TRITON_ATTN backend.
# Loading safetensors checkpoint shards:   0% Completed | 0/4 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:  25% Completed | 1/4 [00:22<01:08, 22.70s/it]
# Loading safetensors checkpoint shards:  50% Completed | 2/4 [00:45<00:44, 22.48s/it]
# Loading safetensors checkpoint shards:  75% Completed | 3/4 [01:10<00:24, 24.03s/it]
# Loading safetensors checkpoint shards: 100% Completed | 4/4 [01:15<00:00, 16.27s/it]
# Loading safetensors checkpoint shards: 100% Completed | 4/4 [01:15<00:00, 18.82s/it]
# (Worker pid=119) (Worker_TP0 pid=119)
# (Worker pid=119) (Worker_TP0 pid=119) INFO 05-02 07:31:12 [default_loader.py:293] Loading weights took 75.31 seconds
# (Worker pid=119) (Worker_TP0 pid=119) INFO 05-02 07:31:13 [gpu_model_runner.py:4364] Model loading took 7.51 GiB memory and 75.740352 seconds
# (Worker pid=119) (Worker_TP0 pid=119) INFO 05-02 07:31:39 [gpu_worker.py:424] Available KV cache memory: 5.04 GiB
# (EngineCore_DP0 pid=94) INFO 05-02 07:31:39 [kv_cache_utils.py:1314] GPU KV cache size: 82,592 tokens
# (EngineCore_DP0 pid=94) INFO 05-02 07:31:39 [kv_cache_utils.py:1319] Maximum concurrency for 1,024 tokens per request: 80.66x
# (EngineCore_DP0 pid=94) INFO 05-02 07:31:40 [core.py:282] init engine (profile, create kv cache, warmup model) took 27.23 seconds
# (EngineCore_DP0 pid=94) INFO 05-02 07:31:44 [vllm.py:747] Asynchronous scheduling is enabled.
# (EngineCore_DP0 pid=94) WARNING 05-02 07:31:44 [vllm.py:781] Enforce eager set, disabling torch.compile and CUDAGraphs. This is equivalent to setting -cc.mode=none -cc.cudagraph_mode=none
# (EngineCore_DP0 pid=94) WARNING 05-02 07:31:44 [vllm.py:792] Inductor compilation was disabled by user settings, optimizations settings that are only active during inductor compilation will be ignored.
# (EngineCore_DP0 pid=94) INFO 05-02 07:31:44 [vllm.py:957] Cudagraph is disabled under eager mode
# INFO 05-02 07:31:44 [llm.py:388] Supported tasks: ['generate']
# [00:03:11] [llama_31_8B_Instruct] vLLM engine ready, starting inference (5 rows) ...
# Rendering prompts:   0%|          | 0/5 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/5 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# (Worker pid=119) (Worker_TP0 pid=119) /usr/local/lib/python3.12/dist-packages/xgrammar/kernels/apply_token_bitmask_inplace_triton.py:109: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
# (Worker pid=119) (Worker_TP0 pid=119)   indices_cpu = torch.tensor(indices, dtype=torch.int32)
# (Worker pid=120) (Worker_TP1 pid=120) /usr/local/lib/python3.12/dist-packages/xgrammar/kernels/apply_token_bitmask_inplace_triton.py:109: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
# (Worker pid=120) (Worker_TP1 pid=120)   indices_cpu = torch.tensor(indices, dtype=torch.int32)
# (Worker pid=119) (Worker_TP0 pid=119) /usr/local/lib/python3.12/dist-packages/xgrammar/kernels/apply_token_bitmask_inplace_triton.py:109: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
# (Worker pid=119) (Worker_TP0 pid=119)   indices_cpu = torch.tensor(indices, dtype=torch.int32)
# (Worker pid=120) (Worker_TP1 pid=120) /usr/local/lib/python3.12/dist-packages/xgrammar/kernels/apply_token_bitmask_inplace_triton.py:109: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
# (Worker pid=120) (Worker_TP1 pid=120)   indices_cpu = torch.tensor(indices, dtype=torch.int32)
# [00:03:25] [llama_31_8B_Instruct] inference done — 14.0s  (0.4 rows/s)
# (Worker pid=120) (Worker_TP1 pid=120) INFO 05-02 07:31:59 [multiproc_executor.py:749] Parent process exited, terminating worker
# (Worker pid=119) (Worker_TP0 pid=119) INFO 05-02 07:31:59 [multiproc_executor.py:749] Parent process exited, terminating worker
# (Worker pid=120) (Worker_TP1 pid=120) INFO 05-02 07:31:59 [multiproc_executor.py:802] WorkerProc shutting down.
# (Worker pid=119) (Worker_TP0 pid=119) INFO 05-02 07:31:59 [multiproc_executor.py:802] WorkerProc shutting down.
# nanobind: leaked 2 instances!
#  - leaked instance 0x7c565459bca8 of type "xgrammar.xgrammar_bindings.GrammarMatcher"
#  - leaked instance 0x7c565459b4f8 of type "xgrammar.xgrammar_bindings.CompiledGrammar"
# nanobind: leaked 6 types!
#  - leaked type "xgrammar.xgrammar_bindings.CompiledGrammar"
#  - leaked type "xgrammar.xgrammar_bindings.TokenizerInfo"
#  - leaked type "xgrammar.xgrammar_bindings.Grammar"
#  - leaked type "xgrammar.xgrammar_bindings.GrammarMatcher"
#  - leaked type "xgrammar.xgrammar_bindings.BatchGrammarMatcher"
#  - leaked type "xgrammar.xgrammar_bindings.GrammarCompiler"
# nanobind: leaked 51 functions!
#  - leaked function ""
#  - leaked function ""
#  - leaked function "from_ebnf"
#  - leaked function ""
#  - leaked function ""
#  - leaked function ""
#  - leaked function "_detect_metadata_from_hf"
#  - leaked function ""
#  - leaked function ""
#  - leaked function "compile_structural_tag"
#  - leaked function "deserialize_json"
#  - leaked function "find_jump_forward_string"
#  - leaked function "_debug_print_internal_state"
#  - leaked function "union"
#  - leaked function "accept_token"
#  - leaked function "from_structural_tag"
#  - leaked function "deserialize_json"
#  - leaked function "batch_accept_token"
#  - leaked function "concat"
#  - leaked function "accept_string"
#  - leaked function ""
#  - leaked function "__init__"
#  - leaked function "serialize_json"
#  - leaked function "batch_fill_next_token_bitmask"
#  - leaked function "__init__"
#  - leaked function "from_json_schema"
#  - leaked function "deserialize_json"
#  - leaked function "compile_builtin_json_grammar"
#  - leaked function "reset"
#  - leaked function ""
#  - leaked function ""
#  - leaked function "__init__"
#  - leaked function "to_string"
#  - leaked function "compile_regex"
#  - leaked function ""
#  - leaked function "from_vocab_and_metadata"
#  - leaked function "is_terminated"
#  - leaked function "compile_json_schema"
#  - leaked function "get_cache_size_bytes"
#  - leaked function "dump_metadata"
#  - leaked function "fill_next_token_bitmask"
#  - leaked function "compile_grammar"
#  - leaked function "rollback"
#  - leaked function "from_regex"
#  - leaked function "batch_accept_string"
#  - leaked function "serialize_json"
#  - leaked function "serialize_json"
#  - leaked function "builtin_json_grammar"
#  - leaked function "clear_cache"
#  - leaked function "__init__"
#  - leaked function ""
# nanobind: this is likely caused by a reference counting issue in the binding code.
# [00:03:31] [llama_31_8B_Instruct] END   — total 210.4s
#
# =================================================================
#   Model 2/3: qwen3_8b  (tp=2)
#   Path: /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-qwen3-8b/models/qwen3_8b
# =================================================================
# [00:03:31] [qwen3_8b] START  (model 2/3, tp=2)
# [00:03:31] [qwen3_8b] tokenizer loaded, starting vLLM init ...
# INFO 05-02 07:32:04 [utils.py:238] non-default args: {'dtype': 'half', 'seed': 42, 'max_model_len': 1024, 'tensor_parallel_size': 2, 'disable_log_stats': True, 'enforce_eager': True, 'attention_config': AttentionConfig(backend=<AttentionBackendEnum.TRITON_ATTN: 'vllm.v1.attention.backends.triton_attn.TritonAttentionBackend'>, flash_attn_version=None, use_prefill_decode_attention=False, flash_attn_max_num_splits_for_cuda_graph=32, use_cudnn_prefill=False, use_trtllm_ragged_deepseek_prefill=True, use_trtllm_attention=None, disable_flashinfer_prefill=False, disable_flashinfer_q_quantization=False, use_prefill_query_quantization=False), 'model': '/kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-qwen3-8b/models/qwen3_8b'}
# INFO 05-02 07:32:23 [model.py:531] Resolved architecture: Qwen3ForCausalLM
# WARNING 05-02 07:32:23 [model.py:1892] Casting torch.bfloat16 to torch.float16.
# INFO 05-02 07:32:23 [model.py:1554] Using max model len 1024
# INFO 05-02 07:32:23 [scheduler.py:231] Chunked prefill is enabled with max_num_batched_tokens=8192.
# WARNING 05-02 07:32:23 [vllm.py:781] Enforce eager set, disabling torch.compile and CUDAGraphs. This is equivalent to setting -cc.mode=none -cc.cudagraph_mode=none
# WARNING 05-02 07:32:23 [vllm.py:792] Inductor compilation was disabled by user settings, optimizations settings that are only active during inductor compilation will be ignored.
# INFO 05-02 07:32:23 [vllm.py:957] Cudagraph is disabled under eager mode
# 2026-05-02 07:32:36.697045: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777707156.722042     459 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777707156.729394     459 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777707156.747147     459 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777707156.747180     459 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777707156.747183     459 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777707156.747185     459 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (EngineCore_DP0 pid=459) INFO 05-02 07:32:44 [core.py:101] Initializing a V1 LLM engine (v0.17.1) with config: model='/kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-qwen3-8b/models/qwen3_8b', speculative_config=None, tokenizer='/kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-qwen3-8b/models/qwen3_8b', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=1024, download_dir=None, load_format=auto, tensor_parallel_size=2, pipeline_parallel_size=1, data_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=True, enable_return_routed_experts=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser='', reasoning_parser_plugin='', enable_in_reasoning=False), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None, kv_cache_metrics=False, kv_cache_metrics_sample=0.01, cudagraph_metrics=False, enable_layerwise_nvtx_tracing=False, enable_mfu_metrics=False, enable_mm_processor_stats=False, enable_logging_iteration_details=False), seed=42, served_model_name=/kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-qwen3-8b/models/qwen3_8b, enable_prefix_caching=True, enable_chunked_prefill=True, pooler_config=None, compilation_config={'level': None, 'mode': <CompilationMode.NONE: 0>, 'debug_dump_path': None, 'cache_dir': '', 'compile_cache_save_format': 'binary', 'backend': 'inductor', 'custom_ops': ['all'], 'splitting_ops': [], 'compile_mm_encoder': False, 'compile_sizes': [], 'compile_ranges_split_points': [8192], 'inductor_compile_config': {'enable_auto_functionalized_v2': False, 'combo_kernels': True, 'benchmark_combo_kernel': True}, 'inductor_passes': {}, 'cudagraph_mode': <CUDAGraphMode.NONE: 0>, 'cudagraph_num_of_warmups': 0, 'cudagraph_capture_sizes': [], 'cudagraph_copy_inputs': False, 'cudagraph_specialize_lora': True, 'use_inductor_graph_partition': False, 'pass_config': {'fuse_norm_quant': True, 'fuse_act_quant': True, 'fuse_attn_quant': False, 'enable_sp': False, 'fuse_gemm_comms': False, 'fuse_allreduce_rms': False}, 'max_cudagraph_capture_size': 0, 'dynamic_shapes_config': {'type': <DynamicShapesType.BACKED: 'backed'>, 'evaluate_guards': False, 'assume_32_bit_indexing': False}, 'local_cache_dir': None, 'fast_moe_cold_start': True, 'static_all_moe_layers': []}
# (EngineCore_DP0 pid=459) WARNING 05-02 07:32:44 [multiproc_executor.py:945] Reducing Torch parallelism from 2 threads to 1 to avoid unnecessary CPU contention. Set OMP_NUM_THREADS in the external environment to tune this value as needed.
# (EngineCore_DP0 pid=459) INFO 05-02 07:32:44 [multiproc_executor.py:134] DP group leader: node_rank=0, node_rank_within_dp=0, master_addr=127.0.0.1, mq_connect_ip=172.19.2.2 (local), world_size=2, local_world_size=2
# 2026-05-02 07:32:49.578153: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-05-02 07:32:49.584495: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777707169.603625     484 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777707169.610723     485 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777707169.611338     484 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1777707169.618880     485 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777707169.631398     484 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777707169.631430     484 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777707169.631433     484 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777707169.631435     484 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777707169.646126     485 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777707169.646170     485 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777707169.646174     485 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777707169.646178     485 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (Worker pid=484) INFO 05-02 07:33:02 [parallel_state.py:1393] world_size=2 rank=0 local_rank=0 distributed_init_method=tcp://127.0.0.1:57397 backend=nccl
# (Worker pid=485) INFO 05-02 07:33:02 [parallel_state.py:1393] world_size=2 rank=1 local_rank=1 distributed_init_method=tcp://127.0.0.1:57397 backend=nccl
# [W502 07:33:10.353322001 socket.cpp:207] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W502 07:33:10.598495324 socket.cpp:207] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# (Worker pid=484) <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.cudart module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.runtime module instead.
# (Worker pid=485) <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.cudart module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.runtime module instead.
# (Worker pid=484) <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.nvrtc module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.nvrtc module instead.
# (Worker pid=485) <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.nvrtc module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.nvrtc module instead.
# (Worker pid=484) INFO 05-02 07:33:10 [pynccl.py:111] vLLM is using nccl==2.27.5
# (Worker pid=484) WARNING 05-02 07:33:10 [symm_mem.py:67] SymmMemCommunicator: Device capability 7.5 not supported, communicator is not available.
# (Worker pid=485) WARNING 05-02 07:33:10 [symm_mem.py:67] SymmMemCommunicator: Device capability 7.5 not supported, communicator is not available.
# (Worker pid=485) INFO 05-02 07:33:10 [parallel_state.py:1715] rank 1 in world size 2 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 1, EP rank N/A, EPLB rank N/A
# (Worker pid=484) INFO 05-02 07:33:10 [parallel_state.py:1715] rank 0 in world size 2 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 0, EP rank N/A, EPLB rank N/A
# (Worker pid=484) INFO 05-02 07:33:11 [base.py:106] Offloader set to NoopOffloader
# (Worker pid=485) INFO 05-02 07:33:11 [base.py:106] Offloader set to NoopOffloader
# (Worker pid=484) (Worker_TP0 pid=484) INFO 05-02 07:33:11 [gpu_model_runner.py:4281] Starting to load model /kaggle/input/notebooks/natbrian/0-kaggle-setup-nbme-score-clinical-qwen3-8b/models/qwen3_8b...
# (Worker pid=485) (Worker_TP1 pid=485) INFO 05-02 07:33:12 [cuda.py:368] Using AttentionBackendEnum.TRITON_ATTN backend.
# (Worker pid=484) (Worker_TP0 pid=484) INFO 05-02 07:33:12 [cuda.py:368] Using AttentionBackendEnum.TRITON_ATTN backend.
# Loading safetensors checkpoint shards:   0% Completed | 0/5 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:  20% Completed | 1/5 [00:26<01:46, 26.61s/it]
# Loading safetensors checkpoint shards:  40% Completed | 2/5 [00:54<01:21, 27.33s/it]
# Loading safetensors checkpoint shards:  60% Completed | 3/5 [01:21<00:54, 27.43s/it]
# Loading safetensors checkpoint shards:  80% Completed | 4/5 [01:46<00:26, 26.21s/it]
# Loading safetensors checkpoint shards: 100% Completed | 5/5 [01:51<00:00, 18.80s/it]
# Loading safetensors checkpoint shards: 100% Completed | 5/5 [01:51<00:00, 22.40s/it]
# (Worker pid=484) (Worker_TP0 pid=484)
# (Worker pid=484) (Worker_TP0 pid=484) INFO 05-02 07:35:04 [default_loader.py:293] Loading weights took 112.01 seconds
# (Worker pid=484) (Worker_TP0 pid=484) INFO 05-02 07:35:05 [gpu_model_runner.py:4364] Model loading took 7.64 GiB memory and 112.298254 seconds
# (Worker pid=484) (Worker_TP0 pid=484) INFO 05-02 07:35:30 [gpu_worker.py:424] Available KV cache memory: 4.83 GiB
# (EngineCore_DP0 pid=459) INFO 05-02 07:35:30 [kv_cache_utils.py:1314] GPU KV cache size: 70,368 tokens
# (EngineCore_DP0 pid=459) INFO 05-02 07:35:30 [kv_cache_utils.py:1319] Maximum concurrency for 1,024 tokens per request: 68.72x
# (EngineCore_DP0 pid=459) INFO 05-02 07:35:31 [core.py:282] init engine (profile, create kv cache, warmup model) took 26.22 seconds
# (EngineCore_DP0 pid=459) INFO 05-02 07:35:36 [vllm.py:747] Asynchronous scheduling is enabled.
# (EngineCore_DP0 pid=459) WARNING 05-02 07:35:36 [vllm.py:781] Enforce eager set, disabling torch.compile and CUDAGraphs. This is equivalent to setting -cc.mode=none -cc.cudagraph_mode=none
# (EngineCore_DP0 pid=459) WARNING 05-02 07:35:36 [vllm.py:792] Inductor compilation was disabled by user settings, optimizations settings that are only active during inductor compilation will be ignored.
# (EngineCore_DP0 pid=459) INFO 05-02 07:35:36 [vllm.py:957] Cudagraph is disabled under eager mode
# INFO 05-02 07:35:36 [llm.py:388] Supported tasks: ['generate']
# [00:07:03] [qwen3_8b] vLLM engine ready, starting inference (5 rows) ...
# Rendering prompts:   0%|          | 0/5 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/5 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# (Worker pid=484) (Worker_TP0 pid=484) /usr/local/lib/python3.12/dist-packages/xgrammar/kernels/apply_token_bitmask_inplace_triton.py:109: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
# (Worker pid=484) (Worker_TP0 pid=484)   indices_cpu = torch.tensor(indices, dtype=torch.int32)
# (Worker pid=485) (Worker_TP1 pid=485) /usr/local/lib/python3.12/dist-packages/xgrammar/kernels/apply_token_bitmask_inplace_triton.py:109: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
# (Worker pid=485) (Worker_TP1 pid=485)   indices_cpu = torch.tensor(indices, dtype=torch.int32)
# (Worker pid=485) (Worker_TP1 pid=485) /usr/local/lib/python3.12/dist-packages/xgrammar/kernels/apply_token_bitmask_inplace_triton.py:109: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
# (Worker pid=485) (Worker_TP1 pid=485)   indices_cpu = torch.tensor(indices, dtype=torch.int32)
# (Worker pid=484) (Worker_TP0 pid=484) /usr/local/lib/python3.12/dist-packages/xgrammar/kernels/apply_token_bitmask_inplace_triton.py:109: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
# (Worker pid=484) (Worker_TP0 pid=484)   indices_cpu = torch.tensor(indices, dtype=torch.int32)
# [00:07:12] [qwen3_8b] inference done — 9.1s  (0.5 rows/s)
# (Worker pid=484) (Worker_TP0 pid=484) INFO 05-02 07:35:46 [multiproc_executor.py:749] Parent process exited, terminating worker
# (Worker pid=485) (Worker_TP1 pid=485) INFO 05-02 07:35:46 [multiproc_executor.py:749] Parent process exited, terminating worker
# (Worker pid=484) (Worker_TP0 pid=484) INFO 05-02 07:35:47 [multiproc_executor.py:802] WorkerProc shutting down.
# (Worker pid=485) (Worker_TP1 pid=485) INFO 05-02 07:35:47 [multiproc_executor.py:802] WorkerProc shutting down.
# nanobind: leaked 2 instances!
#  - leaked instance 0x7e42806b86a8 of type "xgrammar.xgrammar_bindings.GrammarMatcher"
#  - leaked instance 0x7e42806b8318 of type "xgrammar.xgrammar_bindings.CompiledGrammar"
# nanobind: leaked 6 types!
#  - leaked type "xgrammar.xgrammar_bindings.CompiledGrammar"
#  - leaked type "xgrammar.xgrammar_bindings.TokenizerInfo"
#  - leaked type "xgrammar.xgrammar_bindings.Grammar"
#  - leaked type "xgrammar.xgrammar_bindings.GrammarMatcher"
#  - leaked type "xgrammar.xgrammar_bindings.BatchGrammarMatcher"
#  - leaked type "xgrammar.xgrammar_bindings.GrammarCompiler"
# nanobind: leaked 51 functions!
#  - leaked function "fill_next_token_bitmask"
#  - leaked function ""
#  - leaked function ""
#  - leaked function "__init__"
#  - leaked function "deserialize_json"
#  - leaked function "from_regex"
#  - leaked function ""
#  - leaked function "__init__"
#  - leaked function "serialize_json"
#  - leaked function "_detect_metadata_from_hf"
#  - leaked function "__init__"
#  - leaked function "concat"
#  - leaked function "compile_grammar"
#  - leaked function "batch_fill_next_token_bitmask"
#  - leaked function "accept_token"
#  - leaked function "dump_metadata"
#  - leaked function "compile_regex"
#  - leaked function "to_string"
#  - leaked function "batch_accept_token"
#  - leaked function ""
#  - leaked function "rollback"
#  - leaked function "from_vocab_and_metadata"
#  - leaked function "serialize_json"
#  - leaked function "is_terminated"
#  - leaked function "clear_cache"
#  - leaked function ""
#  - leaked function ""
#  - leaked function "from_ebnf"
#  - leaked function ""
#  - leaked function "builtin_json_grammar"
#  - leaked function "accept_string"
#  - leaked function "_debug_print_internal_state"
#  - leaked function "reset"
#  - leaked function "get_cache_size_bytes"
#  - leaked function ""
#  - leaked function "compile_builtin_json_grammar"
#  - leaked function "batch_accept_string"
#  - leaked function "compile_structural_tag"
#  - leaked function "__init__"
#  - leaked function "find_jump_forward_string"
#  - leaked function "serialize_json"
#  - leaked function ""
#  - leaked function "deserialize_json"
#  - leaked function ""
#  - leaked function "deserialize_json"
#  - leaked function "from_structural_tag"
#  - leaked function ""
#  - leaked function ""
#  - leaked function "union"
#  - leaked function "compile_json_schema"
#  - leaked function "from_json_schema"
# nanobind: this is likely caused by a reference counting issue in the binding code.
# [00:07:18] [qwen3_8b] END   — total 227.4s
#
# =================================================================
#   Model 3/3: mistral_7b_instruct_v03  (tp=2)
#   Path: /kaggle/input/notebooks/natbrian/mistral-7b-instruct-v0-3/models/mistral_7b_instruct_v03
# =================================================================
# [00:07:18] [mistral_7b_instruct_v03] START  (model 3/3, tp=2)
# [00:07:19] [mistral_7b_instruct_v03] tokenizer loaded, starting vLLM init ...
# INFO 05-02 07:35:51 [utils.py:238] non-default args: {'dtype': 'half', 'seed': 42, 'max_model_len': 1024, 'tensor_parallel_size': 2, 'disable_log_stats': True, 'enforce_eager': True, 'attention_config': AttentionConfig(backend=<AttentionBackendEnum.TRITON_ATTN: 'vllm.v1.attention.backends.triton_attn.TritonAttentionBackend'>, flash_attn_version=None, use_prefill_decode_attention=False, flash_attn_max_num_splits_for_cuda_graph=32, use_cudnn_prefill=False, use_trtllm_ragged_deepseek_prefill=True, use_trtllm_attention=None, disable_flashinfer_prefill=False, disable_flashinfer_q_quantization=False, use_prefill_query_quantization=False), 'model': '/kaggle/input/notebooks/natbrian/mistral-7b-instruct-v0-3/models/mistral_7b_instruct_v03'}
# INFO 05-02 07:36:11 [model.py:531] Resolved architecture: MistralForCausalLM
# WARNING 05-02 07:36:11 [model.py:1892] Casting torch.bfloat16 to torch.float16.
# INFO 05-02 07:36:11 [model.py:1554] Using max model len 1024
# INFO 05-02 07:36:11 [scheduler.py:231] Chunked prefill is enabled with max_num_batched_tokens=8192.
# WARNING 05-02 07:36:11 [vllm.py:781] Enforce eager set, disabling torch.compile and CUDAGraphs. This is equivalent to setting -cc.mode=none -cc.cudagraph_mode=none
# WARNING 05-02 07:36:11 [vllm.py:792] Inductor compilation was disabled by user settings, optimizations settings that are only active during inductor compilation will be ignored.
# INFO 05-02 07:36:11 [vllm.py:957] Cudagraph is disabled under eager mode
# 2026-05-02 07:36:24.589504: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777707384.618983     782 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777707384.627915     782 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777707384.649106     782 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777707384.649177     782 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777707384.649185     782 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777707384.649190     782 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (EngineCore_DP0 pid=782) INFO 05-02 07:36:32 [core.py:101] Initializing a V1 LLM engine (v0.17.1) with config: model='/kaggle/input/notebooks/natbrian/mistral-7b-instruct-v0-3/models/mistral_7b_instruct_v03', speculative_config=None, tokenizer='/kaggle/input/notebooks/natbrian/mistral-7b-instruct-v0-3/models/mistral_7b_instruct_v03', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=1024, download_dir=None, load_format=auto, tensor_parallel_size=2, pipeline_parallel_size=1, data_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=True, enable_return_routed_experts=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser='', reasoning_parser_plugin='', enable_in_reasoning=False), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None, kv_cache_metrics=False, kv_cache_metrics_sample=0.01, cudagraph_metrics=False, enable_layerwise_nvtx_tracing=False, enable_mfu_metrics=False, enable_mm_processor_stats=False, enable_logging_iteration_details=False), seed=42, served_model_name=/kaggle/input/notebooks/natbrian/mistral-7b-instruct-v0-3/models/mistral_7b_instruct_v03, enable_prefix_caching=True, enable_chunked_prefill=True, pooler_config=None, compilation_config={'level': None, 'mode': <CompilationMode.NONE: 0>, 'debug_dump_path': None, 'cache_dir': '', 'compile_cache_save_format': 'binary', 'backend': 'inductor', 'custom_ops': ['all'], 'splitting_ops': [], 'compile_mm_encoder': False, 'compile_sizes': [], 'compile_ranges_split_points': [8192], 'inductor_compile_config': {'enable_auto_functionalized_v2': False, 'combo_kernels': True, 'benchmark_combo_kernel': True}, 'inductor_passes': {}, 'cudagraph_mode': <CUDAGraphMode.NONE: 0>, 'cudagraph_num_of_warmups': 0, 'cudagraph_capture_sizes': [], 'cudagraph_copy_inputs': False, 'cudagraph_specialize_lora': True, 'use_inductor_graph_partition': False, 'pass_config': {'fuse_norm_quant': True, 'fuse_act_quant': True, 'fuse_attn_quant': False, 'enable_sp': False, 'fuse_gemm_comms': False, 'fuse_allreduce_rms': False}, 'max_cudagraph_capture_size': 0, 'dynamic_shapes_config': {'type': <DynamicShapesType.BACKED: 'backed'>, 'evaluate_guards': False, 'assume_32_bit_indexing': False}, 'local_cache_dir': None, 'fast_moe_cold_start': True, 'static_all_moe_layers': []}
# (EngineCore_DP0 pid=782) WARNING 05-02 07:36:32 [multiproc_executor.py:945] Reducing Torch parallelism from 2 threads to 1 to avoid unnecessary CPU contention. Set OMP_NUM_THREADS in the external environment to tune this value as needed.
# (EngineCore_DP0 pid=782) INFO 05-02 07:36:32 [multiproc_executor.py:134] DP group leader: node_rank=0, node_rank_within_dp=0, master_addr=127.0.0.1, mq_connect_ip=172.19.2.2 (local), world_size=2, local_world_size=2
# 2026-05-02 07:36:38.018065: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-05-02 07:36:38.018363: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777707398.045827     807 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777707398.045895     808 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777707398.054456     807 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1777707398.054456     808 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777707398.073818     808 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777707398.073849     808 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777707398.073852     808 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777707398.073855     808 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777707398.076645     807 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777707398.076699     807 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777707398.076705     807 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777707398.076710     807 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# (Worker pid=807) INFO 05-02 07:36:50 [parallel_state.py:1393] world_size=2 rank=0 local_rank=0 distributed_init_method=tcp://127.0.0.1:53531 backend=nccl
# (Worker pid=808) INFO 05-02 07:36:50 [parallel_state.py:1393] world_size=2 rank=1 local_rank=1 distributed_init_method=tcp://127.0.0.1:53531 backend=nccl
# [W502 07:36:58.889647965 socket.cpp:207] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# [W502 07:36:58.116827195 socket.cpp:207] [c10d] The hostname of the client socket cannot be retrieved. err=-3
# (Worker pid=807) <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.cudart module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.runtime module instead.
# (Worker pid=808) <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.cudart module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.runtime module instead.
# (Worker pid=807) <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.nvrtc module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.nvrtc module instead.
# (Worker pid=808) <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.nvrtc module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.nvrtc module instead.
# (Worker pid=807) INFO 05-02 07:36:59 [pynccl.py:111] vLLM is using nccl==2.27.5
# (Worker pid=807) WARNING 05-02 07:36:59 [symm_mem.py:67] SymmMemCommunicator: Device capability 7.5 not supported, communicator is not available.
# (Worker pid=808) WARNING 05-02 07:36:59 [symm_mem.py:67] SymmMemCommunicator: Device capability 7.5 not supported, communicator is not available.
# (Worker pid=808) INFO 05-02 07:36:59 [parallel_state.py:1715] rank 1 in world size 2 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 1, EP rank N/A, EPLB rank N/A
# (Worker pid=807) INFO 05-02 07:36:59 [parallel_state.py:1715] rank 0 in world size 2 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 0, EP rank N/A, EPLB rank N/A
# (Worker pid=808) INFO 05-02 07:37:00 [base.py:106] Offloader set to NoopOffloader
# (Worker pid=807) INFO 05-02 07:37:00 [base.py:106] Offloader set to NoopOffloader
# (Worker pid=807) (Worker_TP0 pid=807) INFO 05-02 07:37:00 [gpu_model_runner.py:4281] Starting to load model /kaggle/input/notebooks/natbrian/mistral-7b-instruct-v0-3/models/mistral_7b_instruct_v03...
# (Worker pid=808) (Worker_TP1 pid=808) INFO 05-02 07:37:00 [cuda.py:368] Using AttentionBackendEnum.TRITON_ATTN backend.
# (Worker pid=807) (Worker_TP0 pid=807) INFO 05-02 07:37:00 [cuda.py:368] Using AttentionBackendEnum.TRITON_ATTN backend.
# Loading safetensors checkpoint shards:   0% Completed | 0/3 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards:  33% Completed | 1/3 [00:22<00:44, 22.19s/it]
# Loading safetensors checkpoint shards:  67% Completed | 2/3 [00:53<00:27, 27.37s/it]
# Loading safetensors checkpoint shards: 100% Completed | 3/3 [01:20<00:00, 27.38s/it]
# Loading safetensors checkpoint shards: 100% Completed | 3/3 [01:20<00:00, 26.86s/it]
# (Worker pid=807) (Worker_TP0 pid=807)
# (Worker pid=807) (Worker_TP0 pid=807) INFO 05-02 07:38:21 [default_loader.py:293] Loading weights took 80.67 seconds
# (Worker pid=807) (Worker_TP0 pid=807) INFO 05-02 07:38:22 [gpu_model_runner.py:4364] Model loading took 6.76 GiB memory and 80.947686 seconds
# (Worker pid=807) (Worker_TP0 pid=807) INFO 05-02 07:38:44 [gpu_worker.py:424] Available KV cache memory: 5.8 GiB
# (EngineCore_DP0 pid=782) INFO 05-02 07:38:44 [kv_cache_utils.py:1314] GPU KV cache size: 94,944 tokens
# (EngineCore_DP0 pid=782) INFO 05-02 07:38:44 [kv_cache_utils.py:1319] Maximum concurrency for 1,024 tokens per request: 92.72x
# (EngineCore_DP0 pid=782) INFO 05-02 07:38:44 [core.py:282] init engine (profile, create kv cache, warmup model) took 22.09 seconds
# (EngineCore_DP0 pid=782) INFO 05-02 07:38:48 [vllm.py:747] Asynchronous scheduling is enabled.
# (EngineCore_DP0 pid=782) WARNING 05-02 07:38:48 [vllm.py:781] Enforce eager set, disabling torch.compile and CUDAGraphs. This is equivalent to setting -cc.mode=none -cc.cudagraph_mode=none
# (EngineCore_DP0 pid=782) WARNING 05-02 07:38:48 [vllm.py:792] Inductor compilation was disabled by user settings, optimizations settings that are only active during inductor compilation will be ignored.
# (EngineCore_DP0 pid=782) INFO 05-02 07:38:48 [vllm.py:957] Cudagraph is disabled under eager mode
# INFO 05-02 07:38:48 [llm.py:388] Supported tasks: ['generate']
# [00:10:16] [mistral_7b_instruct_v03] vLLM engine ready, starting inference (5 rows) ...
# Rendering prompts:   0%|          | 0/5 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/5 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# (Worker pid=808) (Worker_TP1 pid=808) /usr/local/lib/python3.12/dist-packages/xgrammar/kernels/apply_token_bitmask_inplace_triton.py:109: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
# (Worker pid=808) (Worker_TP1 pid=808)   indices_cpu = torch.tensor(indices, dtype=torch.int32)
# (Worker pid=807) (Worker_TP0 pid=807) /usr/local/lib/python3.12/dist-packages/xgrammar/kernels/apply_token_bitmask_inplace_triton.py:109: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
# (Worker pid=807) (Worker_TP0 pid=807)   indices_cpu = torch.tensor(indices, dtype=torch.int32)
# (Worker pid=808) (Worker_TP1 pid=808) /usr/local/lib/python3.12/dist-packages/xgrammar/kernels/apply_token_bitmask_inplace_triton.py:109: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
# (Worker pid=808) (Worker_TP1 pid=808)   indices_cpu = torch.tensor(indices, dtype=torch.int32)
# (Worker pid=807) (Worker_TP0 pid=807) /usr/local/lib/python3.12/dist-packages/xgrammar/kernels/apply_token_bitmask_inplace_triton.py:109: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
# (Worker pid=807) (Worker_TP0 pid=807)   indices_cpu = torch.tensor(indices, dtype=torch.int32)
# [00:10:18] [mistral_7b_instruct_v03] inference done — 2.7s  (1.9 rows/s)
# (Worker pid=808) (Worker_TP1 pid=808) INFO 05-02 07:38:52 [multiproc_executor.py:749] Parent process exited, terminating worker
# (Worker pid=808) (Worker_TP1 pid=808) INFO 05-02 07:38:52 [multiproc_executor.py:802] WorkerProc shutting down.
# (Worker pid=807) (Worker_TP0 pid=807) INFO 05-02 07:38:52 [multiproc_executor.py:749] Parent process exited, terminating worker
# (Worker pid=807) (Worker_TP0 pid=807) INFO 05-02 07:38:52 [multiproc_executor.py:802] WorkerProc shutting down.
# nanobind: leaked 2 instances!
#  - leaked instance 0x79bb9743ada8 of type "xgrammar.xgrammar_bindings.CompiledGrammar"
#  - leaked instance 0x79bb9743b2e8 of type "xgrammar.xgrammar_bindings.GrammarMatcher"
# nanobind: leaked 6 types!
#  - leaked type "xgrammar.xgrammar_bindings.CompiledGrammar"
#  - leaked type "xgrammar.xgrammar_bindings.TokenizerInfo"
#  - leaked type "xgrammar.xgrammar_bindings.Grammar"
#  - leaked type "xgrammar.xgrammar_bindings.GrammarMatcher"
#  - leaked type "xgrammar.xgrammar_bindings.BatchGrammarMatcher"
#  - leaked type "xgrammar.xgrammar_bindings.GrammarCompiler"
# nanobind: leaked 51 functions!
#  - leaked function ""
#  - leaked function "from_vocab_and_metadata"
#  - leaked function ""
#  - leaked function "dump_metadata"
#  - leaked function "compile_builtin_json_grammar"
#  - leaked function "deserialize_json"
#  - leaked function ""
#  - leaked function ""
#  - leaked function "clear_cache"
#  - leaked function "compile_structural_tag"
#  - leaked function "__init__"
#  - leaked function "accept_string"
#  - leaked function "get_cache_size_bytes"
#  - leaked function ""
#  - leaked function "_debug_print_internal_state"
#  - leaked function "builtin_json_grammar"
#  - leaked function "compile_json_schema"
#  - leaked function "deserialize_json"
#  - leaked function "from_ebnf"
#  - leaked function "serialize_json"
#  - leaked function "fill_next_token_bitmask"
#  - leaked function "union"
#  - leaked function "to_string"
#  - leaked function "compile_regex"
#  - leaked function "from_json_schema"
#  - leaked function "concat"
#  - leaked function ""
#  - leaked function ""
#  - leaked function "find_jump_forward_string"
#  - leaked function "compile_grammar"
#  - leaked function "batch_accept_token"
#  - leaked function ""
#  - leaked function "serialize_json"
#  - leaked function "deserialize_json"
#  - leaked function "from_regex"
#  - leaked function "__init__"
#  - leaked function "rollback"
#  - leaked function "from_structural_tag"
#  - leaked function ""
#  - leaked function "__init__"
#  - leaked function ""
#  - leaked function ""
#  - leaked function "accept_token"
#  - leaked function "serialize_json"
#  - leaked function "_detect_metadata_from_hf"
#  - leaked function "batch_accept_string"
#  - leaked function "is_terminated"
#  - leaked function ""
#  - leaked function "__init__"
#  - leaked function "batch_fill_next_token_bitmask"
#  - leaked function "reset"
# nanobind: this is likely caused by a reference counting issue in the binding code.
# [00:10:23] [mistral_7b_instruct_v03] END   — total 185.3s
# [00:10:23] Starting character-level majority vote ...
#
# ▶ Running character-level majority vote ...
# Majority vote: 100%|██████████| 5/5 [00:00<00:00, 121.26it/s]
# [00:10:23] Majority vote done
# [00:10:23] === DONE — total notebook time 00:10:23 ===
#
# =================================================================
#   ✓ Submission saved → /kaggle/working/submission.csv
#   Shape: (5, 2)
#   Non-empty: 5 / 5
#   Timing log → /kaggle/working/timing.log
# =================================================================
#           id location
# 0  00016_000  696 724
# 1  00016_001  669 693
# 2  00016_002  203 217
# 3  00016_003    56 94
# 4  00016_004  222 258
